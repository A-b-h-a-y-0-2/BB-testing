# %%
COMPOSIO_API_KEY="35adjvgxl35dn3hz5o42h"
GOOGLE_CLOUD_PROJECT="onyx-syntax-451614-t2"
GOOGLE_CLOUD_LOCATION="us-central1"
GOOGLE_GENAI_USE_VERTEXAI=False
GOOGLE_API_KEY="AIzaSyClMtAb3R-tcJeq2qQkgLiXt1ftesfcRsg"

# %%
# !composio add github -y
# !composio add gmail -y
# Out:
# Warning: An existing connection for github was found.
#
# > Do you want to replace the existing connection? (y, n): ^C
#
# > Adding integration: Gmail...
#
# Select auth mode:  (OAUTH2, BEARER_TOKEN):

# %%
pip install composio-gemini
# Out:
# Collecting composio-gemini
#   Downloading composio_gemini-0.7.20-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: composio_core<0.8.0,>=0.7.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio-gemini) (0.7.20)
# Requirement already satisfied: google-genai in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio-gemini) (1.24.0)
# Requirement already satisfied: aiohttp in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (3.12.13)
# Requirement already satisfied: requests<3,>=2.31.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (2.32.4)
# Requirement already satisfied: jsonschema<5,>=4.21.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (4.24.0)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (2.32.0)
# Requirement already satisfied: pysher==1.0.8 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (1.0.8)
# Requirement already satisfied: pydantic>=2.6.4 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (2.11.7)
# Requirement already satisfied: importlib-metadata>=4.8.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (8.7.0)
# Requirement already satisfied: jsonref>=1.1.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (1.1.0)
# Requirement already satisfied: inflection>=0.5.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (0.5.1)
# Requirement already satisfied: semver>=2.13.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (3.0.4)
# Requirement already satisfied: click in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (8.2.1)
# Requirement already satisfied: rich<14,>=13.7.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (13.9.4)
# Requirement already satisfied: pyperclip<2,>=1.8.2 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (1.9.0)
# Requirement already satisfied: Pillow<11,>=10.2.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (10.4.0)
# Requirement already satisfied: paramiko>=3.4.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (3.5.1)
# Requirement already satisfied: fastapi in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (0.115.14)
# Requirement already satisfied: uvicorn in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (0.35.0)
# Requirement already satisfied: pyyaml>=6.0.2 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from composio_core<0.8.0,>=0.7.0->composio-gemini) (6.0.2)
# Requirement already satisfied: websocket-client!=0.49 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from pysher==1.0.8->composio_core<0.8.0,>=0.7.0->composio-gemini) (1.8.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from jsonschema<5,>=4.21.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from jsonschema<5,>=4.21.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from jsonschema<5,>=4.21.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from jsonschema<5,>=4.21.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (0.26.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from requests<3,>=2.31.0->composio_core<0.8.0,>=0.7.0->composio-gemini) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from requests<3,>=2.31.0->composio_core<0.8.0,>=0.7.0->composio-gemini) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from requests<3,>=2.31.0->composio_core<0.8.0,>=0.7.0->composio-gemini) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from requests<3,>=2.31.0->composio_core<0.8.0,>=0.7.0->composio-gemini) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from rich<14,>=13.7.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from rich<14,>=13.7.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (2.19.2)
# Requirement already satisfied: zipp>=3.20 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from importlib-metadata>=4.8.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=13.7.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (0.1.2)
# Requirement already satisfied: bcrypt>=3.2 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from paramiko>=3.4.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (4.3.0)
# Requirement already satisfied: cryptography>=3.3 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from paramiko>=3.4.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (45.0.5)
# Requirement already satisfied: pynacl>=1.5 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from paramiko>=3.4.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (1.5.0)
# Requirement already satisfied: cffi>=1.14 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from cryptography>=3.3->paramiko>=3.4.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (1.17.1)
# Requirement already satisfied: pycparser in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=3.3->paramiko>=3.4.1->composio_core<0.8.0,>=0.7.0->composio-gemini) (2.22)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from pydantic>=2.6.4->composio_core<0.8.0,>=0.7.0->composio-gemini) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from pydantic>=2.6.4->composio_core<0.8.0,>=0.7.0->composio-gemini) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from pydantic>=2.6.4->composio_core<0.8.0,>=0.7.0->composio-gemini) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from pydantic>=2.6.4->composio_core<0.8.0,>=0.7.0->composio-gemini) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from aiohttp->composio_core<0.8.0,>=0.7.0->composio-gemini) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from aiohttp->composio_core<0.8.0,>=0.7.0->composio-gemini) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from aiohttp->composio_core<0.8.0,>=0.7.0->composio-gemini) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from aiohttp->composio_core<0.8.0,>=0.7.0->composio-gemini) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from aiohttp->composio_core<0.8.0,>=0.7.0->composio-gemini) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from aiohttp->composio_core<0.8.0,>=0.7.0->composio-gemini) (1.20.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from fastapi->composio_core<0.8.0,>=0.7.0->composio-gemini) (0.46.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from starlette<0.47.0,>=0.40.0->fastapi->composio_core<0.8.0,>=0.7.0->composio-gemini) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->composio_core<0.8.0,>=0.7.0->composio-gemini) (1.3.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from google-genai->composio-gemini) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from google-genai->composio-gemini) (0.28.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from google-genai->composio-gemini) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from google-genai->composio-gemini) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai->composio-gemini) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai->composio-gemini) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai->composio-gemini) (4.9.1)
# Requirement already satisfied: httpcore==1.* in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai->composio-gemini) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai->composio-gemini) (0.16.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/abhay/EMVO/Testing-ground/composio_test/venv/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai->composio-gemini) (0.6.1)
# Downloading composio_gemini-0.7.20-py3-none-any.whl (4.1 kB)
# Installing collected packages: composio-gemini
# Successfully installed composio-gemini-0.7.20
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.adk.agents import Agent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.genai import types
from composio_gemini import Action, ComposioToolSet

from composio import Composio
# Create composio client
toolset = ComposioToolSet()




# ADK config
model = "gemini-2.0-flash-exp"
app_name = "weather_sentiment_agent"
session_id = "1234"
user_id = "user1234"
# Create genai client config
tools = toolset.get_tools( # type: ignore
            actions=[Action.GITHUB_STAR_A_REPOSITORY_FOR_THE_AUTHENTICATED_USER]
    )

# %%
tools
# Out:
# [<function composio_gemini.toolset.ComposioToolSet._wrap_tool.<locals>._execute(owner: str, repo: str)>]

# %%
root_agent = Agent( 
    name=app_name,
    model=model,
    instruction="You are a github utility agent with ability to interact with github APIs",
    tools=tools,
)

# Session and Runner
session_service = InMemorySessionService()
session = session_service.create_session_sync(
    app_name=app_name,
    user_id=user_id,
    session_id=session_id,
)
runner = Runner(
    agent=root_agent,
    
    app_name=app_name,
    session_service=session_service,
)


# Agent Interaction
content = types.Content(
    role="user",
    parts=[
        types.Part(
            text="Star github repository https://github.com/A-b-h-a-y-0-2/radar-multilingual",
        )
    ],
)
events = runner.run(
    user_id=user_id,
    session_id=session_id,
    new_message=content,
)
for event in events:
    if event.is_final_response():
        print("Agent Response: ", event.content.parts[0].text)
# Out:
# [2025-07-07 19:36:10,854][WARNING] Deprecated. Please migrate to the async method.
# [2025-07-07 19:36:13,156][WARNING] Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Agent Response:  I have successfully starred the repository.

# %%
from composio import ComposioToolSet
toolset = ComposioToolSet(api_key="35adjvgxl35dn3hz5o42h")

integration = toolset.get_integration(id="0418a8ed-6017-4fdc-99de-d4861b784529")
# Collect auth params from your users
print(integration.expectedInputFields)

connection_request = toolset.initiate_connection(
    integration_id=integration.id,
    entity_id="default",
)

# Redirect step require for OAuth Flow
print(connection_request.redirectUrl)
print(connection_request.connectedAccountId)


#(venv) abhay@Abhays-MacBook-Air composio_test % python3 agent/integration.py
# [2025-07-07 16:30:21,212][INFO] Actions cache is outdated, refreshing cache...
# []
# https://backend.composio.dev/api/v3/s/TodnaFaa
# 8a2f7843-ca6b-41c0-bb98-21758e63104b
# Out:
# []
# https://backend.composio.dev/api/v3/s/XW1XOwS7
# 7e6be8f3-4b70-4bb7-a7de-4c30496b0bd0

# %%
# !pip freeze > req.txt
